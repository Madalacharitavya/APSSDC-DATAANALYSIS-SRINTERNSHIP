# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'name':['nethra','naramada'],
                'rno':[510,523],
                'branch':['CSE','ECE']})
df
# Out:
#        name  rno branch
# 0    nethra  510    CSE
# 1  naramada  523    ECE

# %%
# TO rename the single column name.
df.rename(columns={'rno':'RNO'},inplace=True)
df
# Out:
#        name  RNO branch
# 0    nethra  510    CSE
# 1  naramada  523    ECE

# %%
# TO rename the all the column names..
df.columns = ['NAME','ROLLNO','BRANCH']
df
# Out:
#        NAME  ROLLNO BRANCH
# 0    nethra     510    CSE
# 1  naramada     523    ECE

# %%
df.rename(columns={'NAME':'Name','ROLLNO':'Rno'},inplace=True)
df
# Out:
#        Name  Rno BRANCH
# 0    nethra  510    CSE
# 1  naramada  523    ECE

# %%
# To rename the index names...
df.index =['A','B']
df
# Out:
#        Name  Rno BRANCH
# A    nethra  510    CSE
# B  naramada  523    ECE

# %%
# To delete the all the row records..
del(df)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df=pd.DataFrame(np.array([[1,2,3],[4,5,6]]))
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
# To delete the all the row records?
df.drop(df.index,inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
# To delete the all the columns
df.drop(df.columns,inplace=True,axis=1)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### File input/Output reading in pandas:

# %%
# To read the .csv file data..
df2 = pd.read_csv('data.csv')
df2
# Out:
#       Name  Rollno Branch  Java  python
# 0   aadyan     419    cse    45      78
# 1    deepu     560    ece    67      90
# 2   nethra     423    eee    67      24
# 3    akhil     234   mech    56      34
# 4  narmada     342  civil    89      90
# 5  krishna     232    ece    27      56
# 6   ganesh     121   mech    78      45
# 7     nani     463    ece    76      72
# 8   aaryan     367    cse    56      45
# 9    nandu     232    eee    56      45

# %%
df2.shape
# Out:
# (10, 5)

# %%
df2.columns
# Out:
# Index(['Name', 'Rollno', 'Branch', 'Java', 'python'], dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# ### sorting:

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
df2.max()
# Out:
# Name               nethra
# Rollno                560
# Branch               mech
# Java                   89
# python                 90
# Total                 179
# Course    webtechnologies
# dtype: object

# %%
df2['Java'].max()
# Out:
# 89

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
# To print the student names in order?
df2.sort_values('Name')
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 8   aaryan     367    cse    56      45    101             java
# 3    akhil     234   mech    56      34     90      DATA Mining
# 1    deepu     560    ece    67      90    157           django
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 5  krishna     232    ece    27      56     83           raptor
# 9    nandu     232    eee    56      45    101    Data Analysis
# 7     nani     463    ece    76      72    148           python
# 4  narmada     342  civil    89      90    179       c-language
# 2   nethra     423    eee    67      24     91           python

# %%
df2.sort_values(by="Name")
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 8   aaryan     367    cse    56      45    101             java
# 3    akhil     234   mech    56      34     90      DATA Mining
# 1    deepu     560    ece    67      90    157           django
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 5  krishna     232    ece    27      56     83           raptor
# 9    nandu     232    eee    56      45    101    Data Analysis
# 7     nani     463    ece    76      72    148           python
# 4  narmada     342  civil    89      90    179       c-language
# 2   nethra     423    eee    67      24     91           python

# %%
df2.sort_values('Java',ascending=False)
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 4  narmada     342  civil    89      90    179       c-language
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 5  krishna     232    ece    27      56     83           raptor

# %%
# To sort the mutliple columns
df2.sort_values(['Java','python'])
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 5  krishna     232    ece    27      56     83           raptor
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 3    akhil     234   mech    56      34     90      DATA Mining
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis
# 2   nethra     423    eee    67      24     91           python
# 1    deepu     560    ece    67      90    157           django
# 7     nani     463    ece    76      72    148           python
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 4  narmada     342  civil    89      90    179       c-language

# %%
# To add the two subject marks..
df2['Total']=df2['Java']+df2['python']
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
df2.loc[(df2["Java"]>50) & (df2["python"]>50)]
# Out:
#       Name  Rollno Branch  Java  python  Total      Course
# 1    deepu     560    ece    67      90    157      django
# 4  narmada     342  civil    89      90    179  c-language
# 7     nani     463    ece    76      72    148      python

# %%
df2[(df2['Java']>50) & (df2['python']>50)]
# Out:
#       Name  Rollno Branch  Java  python  Total      Course
# 1    deepu     560    ece    67      90    157      django
# 4  narmada     342  civil    89      90    179  c-language
# 7     nani     463    ece    76      72    148      python

# %% [markdown]
# ### Filtering:

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
df2['Java'].max()
# Out:
# 89

# %%
df2['Java'].min()
# Out:
# 27

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
df2['Course']=['Data Analysis','django','python','DATA Mining',
              'c-language','raptor','webtechnologies','python','java','Data Analysis']
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
df2['Course'].value_counts()
# Out:
# Data Analysis      2
# python             2
# django             1
# DATA Mining        1
# c-language         1
# raptor             1
# webtechnologies    1
# java               1
# Name: Course, dtype: int64

# %%
# To print the only python student records.
df2[df2['Course']=='python']
# Out:
#      Name  Rollno Branch  Java  python  Total  Course
# 2  nethra     423    eee    67      24     91  python
# 7    nani     463    ece    76      72    148  python

# %%
# To print the cse student records
df2[df2['Branch']=='cse']
# Out:
#      Name  Rollno Branch  Java  python  Total         Course
# 0  aadyan     419    cse    45      78    123  Data Analysis
# 8  aaryan     367    cse    56      45    101           java

# %%
print(len(df2[df2['Branch'] == 'cse']))
# Out:
# 2

# %%
print(len(df2[df2['Course']=='python']))
# Out:
# 2

# %%
df2.count()
# Out:
# Name      10
# Rollno    10
# Branch    10
# Java      10
# python    10
# Total     10
# Course    10
# dtype: int64

# %%
df2['Course'].count()
# Out:
# 10

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
# To print the student name starts with 'a' from dataset?
df2[df2['Name'].str.startswith('a')]
# Out:
#      Name  Rollno Branch  Java  python  Total         Course
# 0  aadyan     419    cse    45      78    123  Data Analysis
# 3   akhil     234   mech    56      34     90    DATA Mining
# 8  aaryan     367    cse    56      45    101           java

# %%
df2
# Out:
#       Name  Rollno Branch  Java  python  Total           Course
# 0   aadyan     419    cse    45      78    123    Data Analysis
# 1    deepu     560    ece    67      90    157           django
# 2   nethra     423    eee    67      24     91           python
# 3    akhil     234   mech    56      34     90      DATA Mining
# 4  narmada     342  civil    89      90    179       c-language
# 5  krishna     232    ece    27      56     83           raptor
# 6   ganesh     121   mech    78      45    123  webtechnologies
# 7     nani     463    ece    76      72    148           python
# 8   aaryan     367    cse    56      45    101             java
# 9    nandu     232    eee    56      45    101    Data Analysis

# %%
# TO print the highest total marks student record from a df?
df2[df2['Total']==df2['Total'].max()]
# Out:
#       Name  Rollno Branch  Java  python  Total      Course
# 4  narmada     342  civil    89      90    179  c-language

# %%
df3 = df2.sort_values('Total',ascending=False)
df3.head(1)
# Out:
#       Name  Rollno Branch  Java  python  Total      Course
# 4  narmada     342  civil    89      90    179  c-language
