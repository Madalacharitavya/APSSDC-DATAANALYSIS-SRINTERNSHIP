# %% [markdown]
# ## data cleaning:
# * 1. isnull() : TO check the data having null values or not.
# * 2. notnull(): To get the not null values.
# * 3. dropna(): To remove the null values.
# * 4. fillna(): To fill the null values with meaningfull data.
# * 5. replace(): To replace the data
# * 6. sort_values(): To sort the data
# * 7. NaN : Not a number

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Salary_Data.csv')
df
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
#1. isnull() : TO check the data having null values
df.isnull()
# Out:
#         Age  Gender  Edu_Level  Job_Title    YOE  Salary
# 0     False   False      False      False  False   False
# 1     False   False      False      False  False   False
# 2     False   False      False      False  False   False
# 3     False   False      False      False   True   False
# 4     False   False      False      False  False   False
# ...     ...     ...        ...        ...    ...     ...
# 6699  False   False      False      False  False   False
# 6700  False   False      False      False  False   False
# 6701  False   False      False      False  False   False
# 6702  False   False      False      False  False   False
# 6703  False   False      False      False  False   False
#
# [6704 rows x 6 columns]

# %%
# To print the number of null values
df.isnull().sum()
# Out:
# Age          2
# Gender       2
# Edu_Level    3
# Job_Title    2
# YOE          5
# Salary       5
# dtype: int64

# %%
# To print the only null va;ue records
df[df.isnull().any(axis=1)]
#print(len(df[df.isnull().any(axis=1)]))
# Out:
#        Age  Gender          Edu_Level                  Job_Title  YOE  \
# 3     36.0  Female         Bachelor's            Sales Associate  NaN
# 97    26.0    Male         Bachelor's  Junior Software Developer  NaN
# 172    NaN     NaN                NaN                        NaN  NaN
# 260    NaN     NaN                NaN                        NaN  NaN
# 2011  27.0    Male                NaN                  Developer  7.0
# 3136  31.0    Male    Master's Degree        Full Stack Engineer  8.0
# 5247  26.0  Female  Bachelor's Degree                   Social M  NaN
# 6455  36.0    Male  Bachelor's Degree             Sales Director  6.0
#
#         Salary
# 3      60000.0
# 97     35000.0
# 172        NaN
# 260        NaN
# 2011  100000.0
# 3136       NaN
# 5247       NaN
# 6455       NaN

# %%
# notnull()
df.notnull()
# Out:
#        Age  Gender  Edu_Level  Job_Title    YOE  Salary
# 0     True    True       True       True   True    True
# 1     True    True       True       True   True    True
# 2     True    True       True       True   True    True
# 3     True    True       True       True  False    True
# 4     True    True       True       True   True    True
# ...    ...     ...        ...        ...    ...     ...
# 6699  True    True       True       True   True    True
# 6700  True    True       True       True   True    True
# 6701  True    True       True       True   True    True
# 6702  True    True       True       True   True    True
# 6703  True    True       True       True   True    True
#
# [6704 rows x 6 columns]

# %%
# To count the not null records?
df.notnull().sum()
# Out:
# Age          6702
# Gender       6702
# Edu_Level    6701
# Job_Title    6702
# YOE          6699
# Salary       6699
# dtype: int64

# %%
print(len(df.notnull()))
# Out:
# 6704

# %%
# To print the not null records.
df[df.notnull().all(axis=1)]
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# 5     29.0    Male         Bachelor's      Marketing Analyst   2.0   55000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6696 rows x 6 columns]

# %%
# dropna(): To remove the null values..
df.dropna()
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# 5     29.0    Male         Bachelor's      Marketing Analyst   2.0   55000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6696 rows x 6 columns]

# %%
#4. fillna(): To fill the null values with meaningfull data.
df.fillna('missing_value',inplace=True)
df
# Out:
#        Age  Gender          Edu_Level              Job_Title            YOE  \
# 0     32.0    Male         Bachelor's      Software Engineer            5.0
# 1     28.0  Female                PHD           Data Analyst            3.0
# 2     45.0    Male                PhD         Senior Manager           15.0
# 3     36.0  Female         Bachelor's        Sales Associate  missing_value
# 4     52.0    Male           Master's               Director           20.0
# ...    ...     ...                ...                    ...            ...
# 6699  49.0  Female                PhD  Director of Marketing           20.0
# 6700  32.0    Male        High School        Sales Associate            3.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager            4.0
# 6702  46.0    Male    Master's Degree      Marketing Manager           14.0
# 6703  26.0  Female        High School        Sales Executive            1.0
#
#         Salary
# 0      90000.0
# 1      65000.0
# 2     150000.0
# 3      60000.0
# 4     200000.0
# ...        ...
# 6699  200000.0
# 6700   50000.0
# 6701   55000.0
# 6702  140000.0
# 6703   35000.0
#
# [6704 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Age          0
# Gender       0
# Edu_Level    0
# Job_Title    0
# YOE          0
# Salary       0
# dtype: int64

# %%
df
# Out:
#        Age  Gender          Edu_Level              Job_Title            YOE  \
# 0     32.0    Male         Bachelor's      Software Engineer            5.0
# 1     28.0  Female                PHD           Data Analyst            3.0
# 2     45.0    Male                PhD         Senior Manager           15.0
# 3     36.0  Female         Bachelor's        Sales Associate  missing_value
# 4     52.0    Male           Master's               Director           20.0
# ...    ...     ...                ...                    ...            ...
# 6699  49.0  Female                PhD  Director of Marketing           20.0
# 6700  32.0    Male        High School        Sales Associate            3.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager            4.0
# 6702  46.0    Male    Master's Degree      Marketing Manager           14.0
# 6703  26.0  Female        High School        Sales Executive            1.0
#
#         Salary
# 0      90000.0
# 1      65000.0
# 2     150000.0
# 3      60000.0
# 4     200000.0
# ...        ...
# 6699  200000.0
# 6700   50000.0
# 6701   55000.0
# 6702  140000.0
# 6703   35000.0
#
# [6704 rows x 6 columns]

# %%
df1 = pd.read_csv('Salary_Data.csv')
df1
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df1.fillna('1',inplace=True)
df1
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate     1   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df2 = pd.read_csv('Salary_Data.csv')
df2
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
# To fill the specifi column name null values
df2['Gender'].fillna('hello',inplace=True)
df2
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df2.isnull().sum()
# Out:
# Age          2
# Gender       0
# Edu_Level    3
# Job_Title    2
# YOE          5
# Salary       5
# dtype: int64

# %%
# * 5. replace(): To replace the data
df.replace(to_replace='missing_value',value='hai',inplace=True)
df
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   hai   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
# To based on the specific column name
df['Gender'].replace(to_replace='Male',value='M',inplace=True)
df
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0       M         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0       M                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   hai   60000.0
# 4     52.0       M           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0       M        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0       M    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df['Salary'].replace(to_replace=[90000.0,65000.0],value=[1000,2000],inplace=True)
df
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0       M         Bachelor's      Software Engineer   5.0      1000
# 1     28.0  Female                PHD           Data Analyst   3.0      2000
# 2     45.0       M                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   hai   60000.0
# 4     52.0       M           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0       M        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0       M    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
# drop()
df
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0       M         Bachelor's      Software Engineer   5.0      1000
# 1     28.0  Female                PHD           Data Analyst   3.0      2000
# 2     45.0       M                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   hai   60000.0
# 4     52.0       M           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0       M        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0       M    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df[df["Gender"]=="Female"]
# To print the only female records..
# Out:
#        Age  Gender          Edu_Level                         Job_Title   YOE  \
# 1     28.0  Female                PHD                      Data Analyst   3.0
# 3     36.0  Female         Bachelor's                   Sales Associate   hai
# 6     42.0  Female           Master's                   Product Manager  12.0
# 8     26.0  Female         Bachelor's             Marketing Coordinator   1.0
# 11    48.0  Female         Bachelor's                        HR Manager  18.0
# ...    ...     ...                ...                               ...   ...
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager   7.0
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager  19.0
# 6699  49.0  Female                PhD             Director of Marketing  20.0
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager   4.0
# 6703  26.0  Female        High School                   Sales Executive   1.0
#
#         Salary
# 1         2000
# 3      60000.0
# 6     120000.0
# 8      45000.0
# 11    140000.0
# ...        ...
# 6695      1000
# 6697  190000.0
# 6699  200000.0
# 6701   55000.0
# 6703   35000.0
#
# [3014 rows x 6 columns]

# %%
df
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0       M         Bachelor's      Software Engineer   5.0      1000
# 1     28.0  Female                PHD           Data Analyst   3.0      2000
# 2     45.0       M                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   hai   60000.0
# 4     52.0       M           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0       M        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0       M    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df[df['Gender']=='Female']='F'

# %%
df
# Out:
#        Age Gender        Edu_Level          Job_Title   YOE    Salary
# 0     32.0      M       Bachelor's  Software Engineer   5.0      1000
# 1        F      F                F                  F     F         F
# 2     45.0      M              PhD     Senior Manager  15.0  150000.0
# 3        F      F                F                  F     F         F
# 4     52.0      M         Master's           Director  20.0  200000.0
# ...    ...    ...              ...                ...   ...       ...
# 6699     F      F                F                  F     F         F
# 6700  32.0      M      High School    Sales Associate   3.0   50000.0
# 6701     F      F                F                  F     F         F
# 6702  46.0      M  Master's Degree  Marketing Manager  14.0  140000.0
# 6703     F      F                F                  F     F         F
#
# [6704 rows x 6 columns]

# %%
df2
df2['Gender']=np.where(df['Gender']=='Female',0,1)
df2
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0       1         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0       1                PHD           Data Analyst   3.0   65000.0
# 2     45.0       1                PhD         Senior Manager  15.0  150000.0
# 3     36.0       1         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0       1           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0       1                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0       1        High School        Sales Associate   3.0   50000.0
# 6701  30.0       1  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0       1    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0       1        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df=pd.read_csv('Salary_Data.csv')
df
df.loc[df['Gender'] == 'Female', 'Gender'] = 'F'
# TO update the specific column data..
df
# Out:
#        Age Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0   Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0      F                PHD           Data Analyst   3.0   65000.0
# 2     45.0   Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0      F         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0   Male           Master's               Director  20.0  200000.0
# ...    ...    ...                ...                    ...   ...       ...
# 6699  49.0      F                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0   Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0      F  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0   Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0      F        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df1 = pd.read_csv('Salary_Data.csv')
df1
# Out:
#        Age  Gender          Edu_Level              Job_Title   YOE    Salary
# 0     32.0    Male         Bachelor's      Software Engineer   5.0   90000.0
# 1     28.0  Female                PHD           Data Analyst   3.0   65000.0
# 2     45.0    Male                PhD         Senior Manager  15.0  150000.0
# 3     36.0  Female         Bachelor's        Sales Associate   NaN   60000.0
# 4     52.0    Male           Master's               Director  20.0  200000.0
# ...    ...     ...                ...                    ...   ...       ...
# 6699  49.0  Female                PhD  Director of Marketing  20.0  200000.0
# 6700  32.0    Male        High School        Sales Associate   3.0   50000.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager   4.0   55000.0
# 6702  46.0    Male    Master's Degree      Marketing Manager  14.0  140000.0
# 6703  26.0  Female        High School        Sales Executive   1.0   35000.0
#
# [6704 rows x 6 columns]

# %% [markdown]
# ### Groupby():
# - It is used to group the data.

# %%
gp = df1.groupby('Edu_Level')
gp

# %%
# To print the particular data record...
df3 = gp.get_group("Bachelor's") and df['Job_Title'] == 'Software Engineer'
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 # To print the particular data record...
# ----> 2 df3 = gp.get_group("Bachelor's") and df['Job_Title'] == 'Software Engineer'
#       3 df3
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
gp.ngroups
# Out:
# 8

# %%
# To print only single group name records
gp.get_group('PhD')
# Out:
#        Age  Gender Edu_Level                         Job_Title   YOE    Salary
# 2     45.0    Male       PhD                    Senior Manager  15.0  150000.0
# 9     38.0    Male       PhD                  Senior Scientist  10.0  110000.0
# 17    39.0    Male       PhD                   Senior Engineer  12.0  115000.0
# 28    43.0  Female       PhD                 Senior Consultant  15.0  140000.0
# 34    46.0    Male       PhD                    Senior Manager  20.0  170000.0
# ...    ...     ...       ...                               ...   ...       ...
# 6682  28.0    Male       PhD                 Marketing Manager   4.0   55000.0
# 6685  49.0  Female       PhD  Senior Product Marketing Manager  20.0  200000.0
# 6691  36.0  Female       PhD                 Marketing Manager   9.0   95000.0
# 6696  28.0    Male       PhD              Sales Representative   4.0   55000.0
# 6699  49.0  Female       PhD             Director of Marketing  20.0  200000.0
#
# [1368 rows x 6 columns]

# %%
df[(df['Edu_Level']=='PhD') & (df['Job_Title']=='Marketing Manager')]
# Out:
#        Age Gender Edu_Level          Job_Title   YOE    Salary
# 6262  37.0   Male       PhD  Marketing Manager   7.0   90000.0
# 6276  39.0   Male       PhD  Marketing Manager  10.0  100000.0
# 6287  31.0      F       PhD  Marketing Manager   6.0   75000.0
# 6296  35.0   Male       PhD  Marketing Manager   7.0   90000.0
# 6318  35.0   Male       PhD  Marketing Manager   8.0   80000.0
# 6344  27.0      F       PhD  Marketing Manager   4.0   55000.0
# 6364  35.0      F       PhD  Marketing Manager   8.0   80000.0
# 6383  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6397  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6411  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6425  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6439  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6453  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6468  50.0   Male       PhD  Marketing Manager  18.0  180000.0
# 6474  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6483  35.0      F       PhD  Marketing Manager   8.0   80000.0
# 6502  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6516  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6530  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6544  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6558  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6572  27.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6592  51.0   Male       PhD  Marketing Manager  19.0  190000.0
# 6598  28.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6607  36.0      F       PhD  Marketing Manager   9.0   95000.0
# 6626  28.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6635  36.0      F       PhD  Marketing Manager   9.0   95000.0
# 6654  28.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6663  36.0      F       PhD  Marketing Manager   9.0   95000.0
# 6682  28.0   Male       PhD  Marketing Manager   4.0   55000.0
# 6691  36.0      F       PhD  Marketing Manager   9.0   95000.0
